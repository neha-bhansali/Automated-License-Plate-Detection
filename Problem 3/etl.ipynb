# %% [markdown]
# <a href="https://colab.research.google.com/github/neha-bhansali/Automated-License-Plate-Detection/blob/main/Problem%203/etl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget -O 'nested_data.json' 'https://file.notion.so/f/s/98b0fa4b-2a85-40e0-af20-5a2785c55c92/Untitled.json?id=b6059ad3-5ee5-4f32-84b6-b03e68bdca98&table=block&spaceId=ca71608c-1cc3-4167-857a-24da97c78717&expirationTimestamp=1692885600000&signature=9bnPSJzT_B1ProiZczFxEz5XpGvOZqY8kEW9Bm9DW4Q&downloadName=nested_data.json'
# Out:
# --2023-08-23 13:26:25--  https://file.notion.so/f/s/98b0fa4b-2a85-40e0-af20-5a2785c55c92/Untitled.json?id=b6059ad3-5ee5-4f32-84b6-b03e68bdca98&table=block&spaceId=ca71608c-1cc3-4167-857a-24da97c78717&expirationTimestamp=1692885600000&signature=9bnPSJzT_B1ProiZczFxEz5XpGvOZqY8kEW9Bm9DW4Q&downloadName=nested_data.json
# Resolving file.notion.so (file.notion.so)... 13.224.2.120, 13.224.2.89, 13.224.2.128, ...
# Connecting to file.notion.so (file.notion.so)|13.224.2.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22924462 (22M) [application/json]
# Saving to: ‘nested_data.json’
#
# nested_data.json    100%[===================>]  21.86M  58.3MB/s    in 0.4s
#
# 2023-08-23 13:26:26 (58.3 MB/s) - ‘nested_data.json’ saved [22924462/22924462]

# %%
data = pd.read_json('nested_data.json')

# %%
data.head()
# Out:
#                                             programs
# 0  {'season': '1842-43', 'orchestra': 'New York P...
# 1  {'season': '1842-43', 'orchestra': 'New York P...
# 2  {'season': '1842-43', 'orchestra': 'Musicians ...
# 3  {'season': '1842-43', 'orchestra': 'New York P...
# 4  {'season': '1843-44', 'orchestra': 'New York P...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13954 entries, 0 to 13953
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   programs  13954 non-null  object
# dtypes: object(1)
# memory usage: 109.1+ KB

# %%
data['programs'][3]
# Out:
# {'season': '1842-43',
#  'orchestra': 'New York Philharmonic',
#  'concerts': [{'Date': '1843-04-22T05:00:00Z',
#    'eventType': 'Subscription Season',
#    'Venue': 'Apollo Rooms',
#    'Location': 'Manhattan, NY',
#    'Time': '8:00PM'}],
#  'programID': '5887',
#  'works': [{'workTitle': 'SYMPHONY NO. 2 IN D MAJOR, OP.36',
#    'conductorName': 'Boucher, Alfred',
#    'ID': '52434*',
#    'soloists': [],
#    'composerName': 'Beethoven,  Ludwig  van'},
#   {'workTitle': 'SYMPATHY, HXXVIA:33 (VOICE AND ORCH) (ARR. Loder)',
#    'conductorName': 'Loder, George',
#    'ID': '3666*',
#    'soloists': [{'soloistName': 'Loder, Edward',
#      'soloistRoles': 'S',
#      'soloistInstrument': 'Vocalist'}],
#    'composerName': 'Haydn,  Franz  Joseph'},
#   {'workTitle': "MIDSUMMER NIGHT'S DREAM, OP. 61",
#    'composerName': 'Mendelssohn,  Felix',
#    'conductorName': 'Loder, George',
#    'ID': '5801*1',
#    'soloists': [],
#    'movement': 'Overture'},
# ...

# %%
programs = pd.json_normalize(data['programs'])

# %%
programs.head()
# Out:
#     season                                 orchestra  \
# 0  1842-43                     New York Philharmonic
# 1  1842-43                     New York Philharmonic
# 2  1842-43  Musicians from the New York Philharmonic
# 3  1842-43                     New York Philharmonic
# 4  1843-44                     New York Philharmonic
#
#                                             concerts programID  \
# 0  [{'Date': '1842-12-07T05:00:00Z', 'eventType':...      3853
# 1  [{'Date': '1843-02-18T05:00:00Z', 'eventType':...      5178
# 2  [{'Date': '1843-04-07T05:00:00Z', 'eventType':...     10785
# 3  [{'Date': '1843-04-22T05:00:00Z', 'eventType':...      5887
# 4  [{'Date': '1843-11-18T05:00:00Z', 'eventType':...       305
#
#                                                works  \
# 0  [{'workTitle': 'SYMPHONY NO. 5 IN C MINOR, OP....
# 1  [{'workTitle': 'SYMPHONY NO. 3 IN E FLAT MAJOR...
# 2  [{'workTitle': 'EGMONT, OP.84', 'composerName'...
# ...

# %%
d = pd.json_normalize(data['programs'], 'concerts')

# %%
d
# Out:
#                        Date                      eventType  \
# 0      1842-12-07T05:00:00Z            Subscription Season
# 1      1843-02-18T05:00:00Z            Subscription Season
# 2      1843-04-07T05:00:00Z                        Special
# 3      1843-04-22T05:00:00Z            Subscription Season
# 4      1843-11-18T05:00:00Z            Subscription Season
# ...                     ...                            ...
# 21602  2017-06-24T04:00:00Z                        Chamber
# 21603  2017-07-02T04:00:00Z                           Tour
# 21604  2017-07-03T04:00:00Z                           Tour
# 21605  2017-07-04T04:00:00Z  Tour - Young People's Concert
# 21606  2017-07-07T04:00:00Z                           Tour
#
#                                       Venue          Location    Time
# 0                              Apollo Rooms     Manhattan, NY  8:00PM
# 1                              Apollo Rooms     Manhattan, NY  8:00PM
# ...

# %%
l = pd.json_normalize(data['programs'] , 'works')

# %%
l
# Out:
#                                                workTitle        conductorName  \
# 0                       SYMPHONY NO. 5 IN C MINOR, OP.67  Hill, Ureli Corelli
# 1                                                 OBERON       Timm, Henry C.
# 2                        QUINTET, PIANO, D MINOR, OP. 74                  NaN
# 3                                                    NaN                  NaN
# 4                                                 OBERON    Etienne, Denis G.
# ...                                                  ...                  ...
# 82788                           MEMORIES OF MARNYI STONE       Gersen, Joshua
# 82789  SYMPHONY NO. 9, E MINOR, OP.95 (FROM THE NEW W...       Gersen, Joshua
# 82790                                         QUIET CITY        Gilbert, Alan
# 82791                       JUNGLE, THE (SYMPHONY NO. 4)        Gilbert, Alan
# 82792                                        C JAM BLUES                  NaN
#
# ...

# %%
x = pd.json_normalize(data['programs'] , ['works' , 'soloists'] )

# %%
x
# Out:
#                                              soloistName soloistRoles  \
# 0                                       Otto, Antoinette            S
# 1                                  Scharfenberg, William            A
# 2                                    Hill, Ureli Corelli            A
# 3                                         Derwort, G. H.            A
# 4                                        Boucher, Alfred            A
# ...                                                  ...          ...
# 56189                                         Xu, Weiqin            S
# 56190                                Martin, Christopher            S
# 56191                                     Shryock, Grace            S
# 56192  Jazz at Lincoln Center Orchestra with Wynton M...            S
# 56193  Jazz at Lincoln Center Orchestra with Wynton M...            S
#
#       soloistInstrument
# 0               Soprano
# 1                 Piano
# 2                Violin
# 3                 Viola
# ...
