# %% [markdown]
# <a href="https://colab.research.google.com/github/neha-bhansali/Automated-License-Plate-Detection/blob/main/Problem%2003/streaming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-8-jdk-headless -qq
# !pip install pyspark

# %%
# !mkdir streaming
# Out:
# mkdir: cannot create directory ‘streaming’: File exists

# %%
# !pip install -q findspark

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/usr/local/lib/python3.10/dist-packages/pyspark"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/drive/MyDrive/json_files /content/streaming

# %%
import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
import findspark

findspark.find()
# Out:
# '/usr/local/lib/python3.10/dist-packages/pyspark'

# %%
# Set up SparkSession
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local").appName("Colab").config('spark.ui.port', '4050').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://169ac2fb3792:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
l = os.listdir("/content/streaming/json_files")
for i in range(0,len(l),1):
  l[i] = "/content/streaming/json_files/" + str(l[i])

l
# Out:
# ['/content/streaming/json_files/2018-2-4.jsoncsv',
#  '/content/streaming/json_files/2018-2-8.json',
#  '/content/streaming/json_files/2018-2-7.jsoncsv',
#  '/content/streaming/json_files/2018-2-4.json',
#  '/content/streaming/json_files/2018-2-8.jsoncsv',
#  '/content/streaming/json_files/2018-2-7.json']

# %%
import py

p = []
for i in l:
  p = spark.read.json(i,multiLine = "true")
  p.printSchema()
  p.show()
  p=[]
# Out:
# root
#  |-- 12 Strong: struct (nullable = true)
#  |    |-- Genre: string (nullable = true)
#  |    |-- Gross: string (nullable = true)
#  |    |-- IMDB Metascore: string (nullable = true)
#  |    |-- Popcorn Score: long (nullable = true)
#  |    |-- Rating: string (nullable = true)
#  |    |-- Tomato Score: long (nullable = true)
#  |-- A Ciambra: struct (nullable = true)
#  |    |-- Genre: string (nullable = true)
#  |    |-- Gross: string (nullable = true)
#  |    |-- IMDB Metascore: string (nullable = true)
#  |    |-- Popcorn Score: string (nullable = true)
#  |    |-- Rating: string (nullable = true)
#  |    |-- Tomato Score: string (nullable = true)
#  |-- All The Money In The World: struct (nullable = true)
#  |    |-- popcornscore: long (nullable = true)
#  |    |-- rating: string (nullable = true)
#  |    |-- tomatoscore: long (nullable = true)
#  |-- Along With The Gods: The Two Worlds: struct (nullable = true)
#  |    |-- popcornscore: long (nullable = true)
# ...
